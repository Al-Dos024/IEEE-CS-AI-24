# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Data Loading

# %%
sh = pd.read_csv('netflix1.csv')
sh
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # 3. Exploring Data

# %%
sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
sh.count()
# Out:
# show_id         8790
# type            8790
# title           8790
# director        8790
# country         8790
# date_added      8790
# release_year    8790
# rating          8790
# duration        8790
# listed_in       8790
# dtype: int64

# %%
sh.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
sh.nunique()
# Out:
# show_id         8790
# type               2
# title           8787
# director        4528
# country           86
# date_added      1713
# release_year      74
# rating            14
# duration         220
# listed_in        513
# dtype: int64

# %%
sh.duplicated().any()
# Out:
# False

# %%
sh['show_id'].duplicated().any()
# Out:
# False

# %% [markdown]
# # 4. Data Cleaning

# %%
# set it by the show id
sh = sh.set_index('show_id')
sh
# Out:
#             type                             title         director  \
# show_id
# s1         Movie              Dick Johnson Is Dead  Kirsten Johnson
# s3       TV Show                         Ganglands  Julien Leclercq
# s6       TV Show                     Midnight Mass    Mike Flanagan
# s14        Movie  Confessions of an Invisible Girl    Bruno Garotti
# s8         Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# s8797    TV Show                        Yunus Emre        Not Given
# s8798    TV Show                         Zak Storm        Not Given
# s8801    TV Show                Zindagi Gulzar Hai        Not Given
# s8784    TV Show                              Yoko        Not Given
# s8786    TV Show                               YOM        Not Given
#
#                country  date_added  release_year rating   duration  \
# show_id
# ...

# %%
sh['date_added'] = pd.to_datetime(sh['date_added'])
sh
# Out:
#             type                             title         director  \
# show_id
# s1         Movie              Dick Johnson Is Dead  Kirsten Johnson
# s3       TV Show                         Ganglands  Julien Leclercq
# s6       TV Show                     Midnight Mass    Mike Flanagan
# s14        Movie  Confessions of an Invisible Girl    Bruno Garotti
# s8         Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# s8797    TV Show                        Yunus Emre        Not Given
# s8798    TV Show                         Zak Storm        Not Given
# s8801    TV Show                Zindagi Gulzar Hai        Not Given
# s8784    TV Show                              Yoko        Not Given
# s8786    TV Show                               YOM        Not Given
#
#                country date_added  release_year rating   duration  \
# show_id
# ...

# %% [markdown]
# # Total Content on Netflix

# %%
len(sh)
# Out:
# 8790

# %% [markdown]
# #  Top 10 countries with Netflix Content

# %%
top_10_countries = sh['country'].value_counts().head(10)
top_10_countries
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %% [markdown]
# # Monthly Trend of Movie and TV Show Releases

# %%
sh['month_added'] = sh['date_added'].dt.month
sh
# Out:
#             type                             title         director  \
# show_id
# s1         Movie              Dick Johnson Is Dead  Kirsten Johnson
# s3       TV Show                         Ganglands  Julien Leclercq
# s6       TV Show                     Midnight Mass    Mike Flanagan
# s14        Movie  Confessions of an Invisible Girl    Bruno Garotti
# s8         Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# s8797    TV Show                        Yunus Emre        Not Given
# s8798    TV Show                         Zak Storm        Not Given
# s8801    TV Show                Zindagi Gulzar Hai        Not Given
# s8784    TV Show                              Yoko        Not Given
# s8786    TV Show                               YOM        Not Given
#
#                country date_added  release_year rating   duration  \
# show_id
# ...

# %% [markdown]
# #  Yearly Trend of Movie and TV Show Releases

# %%
sh['year_added']  = sh['date_added'].dt.year
sh
# Out:
#             type                             title         director  \
# show_id
# s1         Movie              Dick Johnson Is Dead  Kirsten Johnson
# s3       TV Show                         Ganglands  Julien Leclercq
# s6       TV Show                     Midnight Mass    Mike Flanagan
# s14        Movie  Confessions of an Invisible Girl    Bruno Garotti
# s8         Movie                           Sankofa     Haile Gerima
# ...          ...                               ...              ...
# s8797    TV Show                        Yunus Emre        Not Given
# s8798    TV Show                         Zak Storm        Not Given
# s8801    TV Show                Zindagi Gulzar Hai        Not Given
# s8784    TV Show                              Yoko        Not Given
# s8786    TV Show                               YOM        Not Given
#
#                country date_added  release_year rating   duration  \
# show_id
# ...

# %% [markdown]
# # Top 10 Movies

# %%
top_10_movies = sh[sh['type'] == 'Movie'].title.value_counts().head(10)
top_10_movies
# Out:
# title
# 22-Jul                                 2
# 15-Aug                                 2
# Dick Johnson Is Dead                   1
# Bottom of the World                    1
# Bobby Sands: 66 Days                   1
# Bobby Robson: More Than a Manager      1
# Bobby                                  1
# Bobbi Jene                             1
# Bob's Broken Sleigh                    1
# Bob Lazar: Area 51 & Flying Saucers    1
# Name: count, dtype: int64

# %%
# opssy seems very wrong *-*

# %% [markdown]
# # Top 10 TV Show

# %% [markdown]
# #  Top_10_Directors
